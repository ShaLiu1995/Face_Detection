# %%
# %run flip_data.py

# %%
# %run vgg16_train.py

# %%
# %run vgg16_val.py

# %%
# %run vgg16_test.py

# %%
# %run train_fc_regression.py
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Training data size: (10000, 25088)
# Training label size: (10000, 4)
# Epoch 1/10
# 10000/10000 [==============================] - 8s 796us/step - loss: 1153.8485
# Epoch 2/10
# 10000/10000 [==============================] - 5s 530us/step - loss: 571.4911
# Epoch 3/10
# 10000/10000 [==============================] - 5s 534us/step - loss: 301.9165
# Epoch 4/10
# ...

# %%
# %run test_fc_regression.py
# Out:
# Drawing output bounding box for resized_img_test_easy completed
# Percentage of IOU > 0.5 on easy set:  0.7756666666666666

# %%
# %matplotlib inline 
# %run single_image.py 'prof_img/prof.png'
# Out:
# 0 conv1_1_W (3, 3, 3, 64)
# 1 conv1_1_b (64,)
# 2 conv1_2_W (3, 3, 64, 64)
# 3 conv1_2_b (64,)
# 4 conv2_1_W (3, 3, 64, 128)
# 5 conv2_1_b (128,)
# 6 conv2_2_W (3, 3, 128, 128)
# 7 conv2_2_b (128,)
# 8 conv3_1_W (3, 3, 128, 256)
# 9 conv3_1_b (256,)
# 10 conv3_2_W (3, 3, 256, 256)
# 11 conv3_2_b (256,)
# 12 conv3_3_W (3, 3, 256, 256)
# 13 conv3_3_b (256,)
# 14 conv4_1_W (3, 3, 256, 512)
# 15 conv4_1_b (512,)
# 16 conv4_2_W (3, 3, 512, 512)
# 17 conv4_2_b (512,)
# 18 conv4_3_W (3, 3, 512, 512)
# 19 conv4_3_b (512,)
# 20 conv5_1_W (3, 3, 512, 512)
# 21 conv5_1_b (512,)
# 22 conv5_2_W (3, 3, 512, 512)
# 23 conv5_2_b (512,)
# 24 conv5_3_W (3, 3, 512, 512)
# 25 conv5_3_b (512,)
# 26 fc6_W (25088, 4096)
# 27 fc6_b (4096,)
# 28 fc7_W (4096, 4096)
# 29 fc7_b (4096,)
# 30 fc8_W (4096, 1000)
# 31 fc8_b (1000,)
# Testing file: prof_img/prof.png
# Testing file shape: (158, 130, 3)
# Bounding box is [24, 21, 64, 89]
# Image saved as "prof_img/prof_labelled.png"
